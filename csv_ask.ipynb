# %% [markdown]
# <a href="https://colab.research.google.com/github/Mo-Alshebli/Mr-Amazing-/blob/main/csv_ask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 35.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 62.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.1 MB/s eta 0:00:00

# %%
import torch
torch.__version__
# Out:
# '2.0.1+cu118'

# %%
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# Out:
# Looking in links: https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.6/107.6 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torch-scatter: filename=torch_scatter-2.1.1-cp310-cp310-linux_x86_64.whl size=491865 sha256=9865626030c5bd011d941d44bf4a1b18db9656478e0b0bb306b0968af42b9676
#   Stored in directory: /root/.cache/pip/wheels/ef/67/58/6566a3b61c6ec0f2ca0c2c324cd035ef2955601f0fb3197d5f
# Successfully built torch-scatter
# ...

# %%
from transformers import pipeline
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
tqa = pipeline(task="table-question-answering",model="google/tapas-base-finetuned-wtq")

# %%
table=pd.read_csv("/content/drive/MyDrive/alrazi/ofp.csv")

# %%
table = table.astype(str)

# %%
query = "what is the best columns for make the ID?"
print(tqa(table=table,query=query)["answer"])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-059fb8bb86eb> in <cell line: 2>()
#       1 query = "what is the best columns for make the ID?"
# ----> 2 print(tqa(table=table,query=query)["answer"])
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/table_question_answering.py in __call__(self, *args, **kwargs)
#     348         pipeline_inputs = self._args_parser(*args, **kwargs)
#     349
# --> 350         results = super().__call__(pipeline_inputs, **kwargs)
#     351         if len(results) == 1:
#     352             return results[0]
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1101                     inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1102                 )
# ...
